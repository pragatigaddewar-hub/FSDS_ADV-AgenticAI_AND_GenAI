# %% [markdown]
# OPERATERS

# %%
11+2
# Out:
# 13

# %%
32-3
# Out:
# 29

# %%
_+5     # _ menas previous value
# Out:
# 42

# %%
_*2  #previous
# Out:
# 84

# %%
5*5
# Out:
# 25

# %%
6/4   # div always ans in float
# Out:
# 1.5

# %%
66//2   #int div always ans in int
# Out:
# 33

# %%
5 % 2    # modulus means remainder
# Out:
# 1

# %%
3**2     # power
# Out:
# 9

# %%
4**3
# Out:
# 64

# %%
1+2
4-2
3*3    # last execute
# Out:
# 9

# %% [markdown]
# VARIABLE

# %%
a=5
a
# Out:
# 5

# %%
var=37
var
# Out:
# 37

# %%
a=4
a
b=3
b      # last execute
# Out:
# 3

# %%
3 * 4
40/5
44//22     # only last
# Out:
# 2

# %%
print(3 * 4)
print(40/5)
print(44//22)    # all print
# Out:
# 12
# 8.0
# 2

# %%
18.2/6   # float div
# Out:
# 3.033333333333333

# %%
14.4//2     # float number --> ans in float
# Out:
# 7.0

# %%
24//6     # int div
