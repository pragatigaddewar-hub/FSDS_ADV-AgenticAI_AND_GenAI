# %% [markdown]
# # tuple ()

# %% [raw]
# - only 2 func
#  index(value)
#  count(value)

# %% [raw]
# - tuple not changable
# - duplicates allow
# - index & slicing not allowed

# %%
t=()
t
# Out:
# ()

# %%
t1=(92,4,5,3)
t1
# Out:
# (92, 4, 5, 3)

# %%
t2=(4,5.5,False,'Pragati',(4+7j))
t2
# Out:
# (4, 5.5, False, 'Pragati', (4+7j))

# %%
print(t)
print(t1)
print(t2)
# Out:
# ()
# (92, 4, 5, 3)
# (4, 5.5, False, 'Pragati', (4+7j))

# %%
t1
# Out:
# (92, 4, 5, 3)

# %%
t1.count(5)
# Out:
# 1

# %%
t1.index(3)
# Out:
# 3

# %%
t1.append(10)
t1                     # append not allow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t1.append(10)
#       2 t1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1[23]       # indexing no allow
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t1[23]
#
# IndexError: tuple index out of range

# %%
t1[2]=133        # tuple not changable
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 t1[2]=133
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t4=t1            # duplicate allow
t4
# Out:
# (92, 4, 5, 3)

# %%
t1
# Out:
# (92, 4, 5, 3)

# %%
t1.pop()       # pop() not allow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t1.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t5=t1*2      #  repeate all elements 
t5           #  duplicate allow
# Out:
# (92, 4, 5, 3, 92, 4, 5, 3)

# %% [markdown]
# # set {}

# %%
- pop()
- add()
- discard()

# %% [raw]
# - empty {} called dict
#
# - if similar datatype, it is in ordered
#    different datatype , it is unordered
#
# - duplicates not allowed
#
# - only 1 argument is allowed in add() func
#
# - index  & slicing not allowed
#
# - pop() gives random value given in the set
#   pop(index) --> error
#
# - only 1 argument allowed
#
# - discard()           --> never error
#   discard(value)      --> remove that value
#
# - remove()    --> error

# %%
s={}
s
# Out:
# {}

# %%
s1={8,10,2,4,5,7}            # same datatype in order
s1
# Out:
# {2, 4, 5, 7, 8, 10}

# %%
s2={3,4,6,4.4,(4+5j),True}     # diff datatype,unorderd
s2
# Out:
# {(4+5j), 3, 4, 4.4, 6, True}

# %%
print(s)
print(s1)
print(s2)
# Out:
# {}
# {2, 4, 5, 7, 8, 10}
# {True, 3, 4, 4.4, 6, (4+5j)}

# %%
s1
# Out:
# {2, 4, 5, 7, 8, 10}

# %%
s1.add(1)
s1
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
s1
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
s1.add(3,2)        only 1 argument allow
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s1.add(3,2)
#       2 s1
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
s1
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
s1.clear()
s1               # all value remove in set
# Out:
# set()

# %%
s2
# Out:
# {(4+5j), 3, 4, 4.4, 6, True}

# %%
s2.copy()
# Out:
# {(4+5j), 3, 4, 4.4, 6, True}

# %%
s2.discard(3)     # remove 3 from set
s2
# Out:
# {(4+5j), 4, 4.4, 6, True}

# %%
s2[3]    # index not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s2[3]
#
# TypeError: 'set' object is not subscriptable

# %%
s2[2:4]      # slicing not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s2[2:4]
#
# TypeError: 'set' object is not subscriptable

# %%
s1={1,3,5,30,24,56}
s1
# Out:
# {1, 3, 5, 24, 30, 56}

# %%
s1.pop()      # gives any random no.
# Out:
# 1

# %%
s1.pop(3)     # index not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s1.pop(3)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s1
# Out:
# {3, 5, 24, 30, 56}

# %%
s1.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 s1.remove(4)
#
# KeyError: 4
