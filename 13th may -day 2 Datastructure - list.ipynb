# %%
l=[]

# %%
l1=[10,45,6.5,'pragati',3,True,(2+3j)]
l1
# Out:
# [10, 45, 6.5, 'pragati', 3, True, (2+3j)]

# %%
l2=[10,20,30,40,50,10,30]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 45, 6.5, 'pragati', 3, True, (2+3j)]
# [10, 20, 30, 40, 50, 10, 30]

# %% [markdown]
# # append()

# %% [markdown]
# l1.append(40)
# l1

# %% [markdown]
# # extend()

# %%
l.extend(l2)
l
# Out:
# [10, 20, 30, 40, 50, 10, 30]

# %%
print(l)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 30]
# [10, 20, 30, 40, 50, 10, 30]

# %%
l1=[10,45,6.5,'pragati',3,True,(2+3j)]
l1
# Out:
# [10, 45, 6.5, 'pragati', 3, True, (2+3j)]

# %%
l4=[2,3,4]
l4
# Out:
# [2, 3, 4]

# %% [markdown]
# #  extend()

# %%
l4.extend(l1)
l4
# Out:
# [2,
#  3,
#  4,
#  10,
#  45,
#  6.5,
#  'pragati',
#  3,
#  True,
#  (2+3j),
#  10,
#  45,
#  6.5,
#  'pragati',
#  3,
#  True,
#  (2+3j)]

# %% [markdown]
# # clear( list no.)

# %%
clear(l3)        # total clear l3

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 30]

# %%
l5=[3,4,5,6]
l5
# Out:
# [3, 4, 5, 6]

# %% [markdown]
# # copy()

# %%
l6=l5.copy()
l6
# Out:
# [3, 4, 5, 6]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 30]

# %% [markdown]
# # index(value)

# %%
l.index(30)        # 1st occurence
# Out:
# 2

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 30]

# %%
l1=[10, 20, 30, 40, 50, 10, 30]
l1
# Out:
# [10, 20, 30, 40, 50, 10, 30]

# %% [markdown]
# # insert(index,value)

# %%
l1.insert(3,37)     # insert(index,value)
l1
# Out:
# [10, 20, 30, 37, 40, 50, 10, 30]

# %% [markdown]
# # pop()

# %% [raw]
# pop()            --> remove last value
# pop(index)       --> remove that specific index value

# %%
l1
# Out:
# [10, 20, 30, 37, 40, 50, 10, 30]

# %%
l1.pop()      # last value remove
l1
# Out:
# [10, 20, 30, 37, 40, 50, 10]

# %%
l1
# Out:
# [10, 20, 30, 37, 40, 50, 10]

# %%
l1.pop(3)         # remove 3rd index value
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %% [markdown]
# # remove(value)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1.remove(40)
l1
# Out:
# [10, 20, 30, 50, 10]

# %% [markdown]
# # reverse()

# %%
l2=[2,4,5,7,5]
l2
# Out:
# [2, 4, 5, 7, 5]

# %%
l2.reverse()
l2
# Out:
# [5, 7, 5, 4, 2]

# %% [markdown]
# # sort

# %% [raw]
# sort()                    --> ascending
# sort(reverse=True)        --> descending

# %%
l4=[2,5,3,6,84,26]
l4
# Out:
# [2, 5, 3, 6, 84, 26]

# %%
l4.sort()
l4
# Out:
# [2, 3, 5, 6, 26, 84]

# %%
l4=[3,5,13,21,643,87]
l4
# Out:
# [3, 5, 13, 21, 643, 87]

# %%
l4.sort(reverse=True)
l4
# Out:
# [643, 87, 21, 13, 5, 3]

# %% [markdown]
# # tunning

# %% [raw]
# - parameter tunning         -->  inbuild sysyem parameter
# - hyperparameter tunning    -->  user change the system parameter

# %%
l=[3,4,2,7,4,84,3]
l
# Out:
# [3, 4, 2, 7, 4, 84, 3]

# %%
l.sort()         # parameter tunning bcoz sort is inbuild fun
                  # in original (reverse=False)
l
# Out:
# [2, 3, 3, 4, 4, 7, 84]

# %%
l1=[2,4,112,6,4,20,90]
l1
# Out:
# [2, 4, 112, 6, 4, 20, 90]

# %%
l1.sort(reverse=True)       # hyperparameter tunning
l1                          # original  (reverse=False)
# Out:
# [112, 90, 20, 6, 4, 4, 2]

# %% [markdown]
# #  double indexing

# %%
l3=[2,5,5.7,10,'pragati',(3+5j),True]
l3
# Out:
# [2, 5, 5.7, 10, 'pragati', (3+5j), True]

# %%
l3[2]
# Out:
# 5.7

# %%
l3[4]
# Out:
# 'pragati'

# %%
l3[4][3]      # p r a g a t i
# Out:
# 'g'

# %%
# how to print a name in vertical

# %%
print(l3[4][0])
print(l3[4][1])
print(l3[4][2])
print(l3[4][3])
print(l3[4][4])
print(l3[4][5])
print(l3[4][6])
# Out:
# p
# r
# a
# g
# a
# t
# i
