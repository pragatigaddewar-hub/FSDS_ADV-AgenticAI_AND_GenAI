# %% [markdown]
# VARIABLES

# %%
# printing the values stored in variables

# %%
first_name= "Pragati"

# %%
last_name="Gaddewar"

# %%
country= 'India'

# %%
city="Mumbai"

# %%
age=45331

# %%
is_married= False

# %%
skills=['python','power BI', 'agen AI']

# %%
pers_info={
          "first_name": "american",
          "last_name":"world",
          "country":"gyd",
           "city":"Mumbai"
}

# %%
# printing the values stored in variables

# %%
print("First_name:",first_name)
print("First_name length:",len(first_name))
print("Last_name:",last_name)
print("Last_name length:",len(last_name))
print("Age:",age)
print("Country:",country)
print("City:",city)
print("Married:",is_married)
print("Skills:",skills)
print("PERS_INFO:",pers_info)
# Out:
# First_name: Pragati
# First_name length: 7
# Last_name: Gaddewar
# Last_name length: 8
# Age: 45331
# Country: India
# City: Mumbai
# Married: False
# Skills: ['python', 'power BI', 'agen AI']
# PERS_INFO: {'first_name': 'american', 'last_name': 'world', 'country': 'gyd', 'city': 'Mumbai'}

# %%
# Declaring multiple variables in one line

# %%
first_name, last_name, country, age, is_married ="Pragati","Gaddewar","India",45331,False

# %%
print(first_name,last_name,country,age,is_married)
print("First_name:",first_name)
print("Last_name:",last_name)
print("Country:",country)
print("Age:",age)
print("Married:",is_married)
# Out:
# Pragati Gaddewar India 45331 False
# First_name: Pragati
# Last_name: Gaddewar
# Country: India
# Age: 45331
# Married: False
