# %% [markdown]
# # print

# %% [raw]
# print is use for ans

# %%
a=5
b=16     # only last var print
a
b
# Out:
# 16

# %%
print(a)
print(b)      # both var print
# Out:
# 5
# 16

# %%
print(18)
print(4,5)                            # display as it is
print('Pragati')
print(4.5,'Pragati',(4+3j))
# Out:
# 18
# 4 5
# Pragati
# 4.5 Pragati (4+3j)

# %%
f=(5,4,3)
print(f)
# Out:
# (5, 4, 3)

# %%
num1=33
num2=66
add=num1+num2
print(add)
# Out:
# 99

# %% [markdown]
# # print result with string

# %%
num1=33
num2=66
add=num1+num2
print('The addition of',num1,'and',num2,'is',add,'.')
# Out:
# The addition of 33 and 66 is 99 .

# %%
name='Pragati'
age=23
country='India'

# %%
print('My name is',name,'.','I am',age,'years old and','i am from',country,'.')
# Out:
# My name is Pragati . I am 23 years old and i am from India .

# %% [markdown]
# # print format method

# %%
num1=33
num2=66
add=num1+num2

# %%
print("The addition of {} and {} is".format(num1,num2),add)
# Out:
# The addition of 33 and 66 is 99

# %%
name='Pragati'
age=23
country='India'

# %%
print("My name is {}, I am {} years old and I am from {}.".format(name,age,country))
# Out:
# My name is Pragati, I am 23 years old and I am from India.

# %% [markdown]
# # avg

# %% [raw]
#  round((a+b+c)/3,2       # means till 2, after decimal

# %%
a=23
b=34
c=22
avg= (a+b+c)/3
avg1= round((a+b+c)/3,2)

# %%
print('The avg value of {}, {} and {} is'.format(a,b,c),avg)
# Out:
# The avg value of 23, 34 and 22 is 26.333333333333332

# %%
print('The avg value of {}, {} and {} is'.format(a,b,c),avg1)
# Out:
# The avg value of 23, 34 and 22 is 26.33

# %% [markdown]
# # f string method

# %%
num1=33
num2=66
add=num1+num2

# %%
print(f'The addition of {num1} and {num2} is {add}.')
# Out:
# The addition of 33 and 66 is 99.

# %%
name='Pragati'
age=23
country='India'

# %%
print(f'My name is {name},I am {age} years old and I am from {country}.')
# Out:
# My name is Pragati,I am 23 years old and I am from India.

# %%
a=23
b=34
c=22
avg= (a+b+c)/3
avg1= round((a+b+c)/3,2)

# %%
print(f'The avg of {a}, {b} and {c} is {avg}.')
# Out:
# The avg of 23, 34 and 22 is 26.333333333333332.

# %%
print(f'The avg of {a}, {b} and {c} is {avg1}.')
# Out:
# The avg of 23, 34 and 22 is 26.33.

# %%
x=4
y=6
add=x+y

# %%
print('The addition of',x,'and',y,'is',add)
print('The addition of {} and {} is'.format(x,y),add)
print(f'The addition of {x} and {y} is {add}')
# Out:
# The addition of 4 and 6 is 10
# The addition of 4 and 6 is 10
# The addition of 4 and 6 is 10

# %% [markdown]
# # end seperator

# %%
print("Hello")
print("Pragati")
# Out:
# Hello
# Pragati

# %%
print("Hello",end="")
print("Pragati")
# Out:
# HelloPragati

# %%
print("Hello",end=" ")
print("Pragati")
# Out:
# Hello Pragati

# %% [markdown]
# # seperator

# %%
# only 1 print use

# %%
print(2 , 4 , 6,sep='**')
# Out:
# 2**4**6

# %%
print('Pragati' , 'Tejal' , 'Teju',sep='=>')
# Out:
# Pragati=>Tejal=>Teju

# %%
print('Pragati' , 'Tejal' , 'Teju',sep=' => ')
# Out:
# Pragati => Tejal => Teju

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end='')
print(3)
# Out:
# 1 23

# %%
print(1,2,end=' ')
print(3)
# Out:
# 1 2 3

# %%
print(1,2,end='',sep='' )
print(3)
# Out:
# 123

# %%
print(1,2,3,sep='@' )
# Out:
# 1@2@3
