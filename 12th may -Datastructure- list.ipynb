# %% [markdown]
# # Data structure

# %% [raw]
# - list
# - tuple              # more than 1 variable
# - set
# - dictionary
# - range

# %% [markdown]
# # list []

# %%
l=[]
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1= [10,20,30,40,50]
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l1)
# Out:
# 5

# %% [raw]
# append

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.append(60)
l1.append(70)
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
len(l1)
# Out:
# 7

# %%
l2=[2,3.3,'pragati',True,(3+4j)]
l2
# Out:
# [2, 3.3, 'pragati', True, (3+4j)]

# %%
len(l2)
# Out:
# 5

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 70]
# [2, 3.3, 'pragati', True, (3+4j)]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 0
# 7
# 5

# %%
print(id(l))          
print(id(l1))       # in different id
print(id(l2))
# Out:
# 2195767163328
# 2195773258112
# 2195767344768

# %%
# list inside list means nested list

# %%
l1 = [10, 20, 30, 40, 50, 60, 70]
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
l1.append(['a','b','c'])
l1                               # double run then added ['a','b','c]  one more time
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
len(l1)
# Out:
# 8

# %%
print(type(l1))
# Out:
# <class 'list'>

# %% [raw]
# list membership
# - in
# - not in

# %%
l3=[2,4,5,7,6]
l3
# Out:
# [2, 4, 5, 7, 6]

# %%
2 in l3
# Out:
# True

# %%
8 in l3
# Out:
# False

# %%
4 not in l3
# Out:
# False

# %%
l3
# Out:
# [2, 4, 5, 7, 6]

# %%
l4=l3.copy()
l4
# Out:
# [2, 4, 5, 7, 6]

# %%
print(id(l3))          # if same number ,in datastructure id are different
print(id(l4))          # if same number ,in datatype id are same
# Out:
# 2195773553408
# 2195773268288

# %%
l4
# Out:
# [2, 4, 5, 7, 6]

# %%
len(l4)
# Out:
# 5

# %%
del (l4)     # permenantly deleted
             # if i double run on it,it gives error bcoz list has already deleted so no ouput

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1.append(10,400)       # it gives error bcoz, we csn pass only 1 argument at a time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 l1.append(10,400)       # it gives error bcoz, we csn pass only 1 argument at a time
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1.append(10)
l1.append(30)     # i run it 2 times that's why 10 & 30 is repeated
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c'], 10, 30, 10, 30]

# %%
l1.count(10)
# Out:
# 3

# %%
l1.count(20)
# Out:
# 1

# %%
l1=[10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %% [raw]
# indexing

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[2:6]
# Out:
# [30, 40, 50, 60]

# %%
l1[3:8]
# Out:
# [40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[2:60]
# Out:
# [30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 l1[1000]
#
# IndexError: list index out of range

# %%
l1[3:1000]
# Out:
# [40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[-6:]
# Out:
# [30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[3:-2]   # count from starting & ending,remaining value
# Out:
# [40, 50, 60]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[0:6:2]
# Out:
# [10, 30, 50]

# %%
l1[ :  : 4]         # start to end whole consider
# Out:
# [10, 50]

# %%
l1[ : : 1]    # whole
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %% [raw]
# reverse

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[ : : -1]     # all reverse
# Out:
# [['a', 'b', 'c'], 70, 60, 50, 40, 30, 20, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[-8: :3]
# Out:
# [10, 40, 70]
