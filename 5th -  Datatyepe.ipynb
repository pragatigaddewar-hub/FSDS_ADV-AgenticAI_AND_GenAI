# %% [markdown]
# 5th

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# int

# %%
a=6
a
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
5 = i 
i                               # variable does not start with digit
# Out:
#   Cell In[8], line 1
#     5= i
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# float

# %%
b=4.4
b
# Out:
# 4.4

# %%
type(b)
# Out:
# float

# %%
2e0
# Out:
# 2.0

# %%
2e1
# Out:
# 20.0

# %%
3E3
# Out:
# 3000.0

# %%
-4e2
# Out:
# -400.0

# %%
2.4e2
# Out:
# 240.0

# %% [markdown]
# bool

# %%
True
# Out:
# True

# %%
false            # False ,not small f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
None

# %%
True + False     # True = 0
                 # False = 1
# Out:
# 1
# 1

# %%
False + False
# Out:
# 0

# %%
t=True
f=False

# %%
print(t+f)
print(t-f)
print(t*f)
print(t/f)
# Out:
# 1
# 1
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[25], line 4
#       2 print(t-f)
#       3 print(t*f)
# ----> 4 print(t/f)
#
# ZeroDivisionError: division by zero

# %%
f//t
# Out:
# 0

# %%
t
# Out:
# True

# %%
type(t)
# Out:
# bool

# %% [markdown]
# complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10+20j
d=20+40j

# %%
print(c+d)
# Out:
# (30+60j)
