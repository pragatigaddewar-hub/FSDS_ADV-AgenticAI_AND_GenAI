# %% [markdown]
# Type Casting

# %%
Convert all datatype to int

# %%
int(34)    # int
# Out:
# 34

# %%
int(2.3)    # float
# Out:
# 2

# %%
int(True)     # bool
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)   # complex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(1+2j)   # complex
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('23')     # no. string
# Out:
# 23

# %% [markdown]
# int('ten')    # text string

# %%
int(2 , 4)     # 2 arguments not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(2 , 4)
#
# TypeError: int() can't convert non-string with explicit base

# %% [markdown]
# Int    complex          X
#
#        text string      X
#
#        2 arguments      X

# %%
 Conver All datatype into float

# %%
float(45)    # int
# Out:
# 45.0

# %%
float(34.54)   # float
# Out:
# 34.54

# %%
float(True)    # bool
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
flaot(3+5j)    # complex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 flaot(3+5j)
#
# NameError: name 'flaot' is not defined

# %%
float("34")    # no. string
# Out:
# 34.0

# %%
float('ten')     # text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# float(2.3 , 3.5)    # 2 arguments not allow

# %% [markdown]
# float      complex            X
#
#            text string        X
#
#            2 arguments        X

# %%
Convert all datatypes to boolean        always ans in True  or False

# %%
# non-zero no. is True 

# zero no. is False

# %%
bool(34)       # int
# Out:
# True

# %%
bool(45.44)     # float
# Out:
# True

# %%
bool(3+4j)    #complex
# Out:
# True

# %%
bool()     # nothing means zero
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0+5j)   # complex = 5j
# Out:
# True

# %%
bool('20')     # no. string
# Out:
# True

# %%
bool('ten')     # text string
# Out:
# True

# %% [markdown]
# bool(None)

# %% [markdown]
# bool      all are possible

# %%
convert all datatypes to complex

# %%
complex(45)    # int
# Out:
# (45+0j)

# %%
complex(12,23)
# Out:
# (12+23j)

# %%
complex(23,45,43)       # 3 arguments not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 complex(23,45,43)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.4)         # float
# Out:
# (2.4+0j)

# %%
complex(3.4 , 4.5)    # 2 argument
# Out:
# (3.4+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,True)
# Out:
# (1+1j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex('23')    # no. string
# Out:
# (23+0j)

# %%
complex('ten')    # text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('45' , '67')        # 2 strings not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 complex('45' , '67')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(6 , '76')      # when it's 2 arg,string is not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 complex(6 , '76')
#
# TypeError: complex() second arg can't be a string

# %%
complex('68' , 75)     # when it's 2 arg,string is not allow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 complex('68' , 75)
#
# TypeError: complex() can't take second arg if first is a string

# %%
 complex       3 argument                   X

               if 2 arg, both are string    X

               if 2 arg, any 1 is string    X

               text string                  X

# %%
Convert  all datatypes into string

# %%
str(34)     # int
# Out:
# '34'

# %%
str('43')     # flaot
# Out:
# '43'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(3+6j)
# Out:
# '(3+6j)'

# %%
string     all are possible

# %% [markdown]
# OPRATORS

# %%
1) Arithmetic  :  + , - , * , / , // , % , **

# %%
a = 5
b = 3

# %%
a + b      # add
# Out:
# 8

# %%
a - b     # substract
# Out:
# 2

# %%
a * b     # mult
# Out:
# 15

# %%
a / b      # div
# Out:
# 1.6666666666666667

# %%
a // b     # int div
# Out:
# 1

# %%
a % b       # modulus
# Out:
# 2

# %%
a ** b      # power
# Out:
# 125

# %% [markdown]
# 2) Assignment   :  += , -+ , *= , /= , //= , %= , **=

# %%
x = 7
x
# Out:
# 7

# %%
x = x + 3
x
# Out:
# 13

# %%
x += 3
x
# Out:
# 19

# %%
x += 5
x
# Out:
# 29

# %%
x *= 2

# %%
x /= 4

# %%
x //=6

# %%
x %= 2

# %%
x **= 8

# %% [markdown]
# 3) Relational / Comparision : < , > , <= , >= , != , ==

# %%
 x = 6
 y = 4

# %%
x < y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
x <= y
# Out:
# False

# %%
x >= y
# Out:
# True

# %%
x != y
# Out:
# True

# %%
x == y
# Out:
# False

# %% [markdown]
# 4) Logical  : and , or , not

# %%
and  T T = T

or   F F = F

not  opposite

# %%
x = 6
y = 3

# %%
x < y   and x > y    # and
# Out:
# False

# %%
x >= y  and  x == y
# Out:
# False

# %%
x != y  or  x < y

 T       or   F       #  T
# Out:
# True

# %%
x < y  or x >= y
# Out:
# True

# %%
not (x < y)
# Out:
# True

# %%
not( x >= y)
# Out:
# False

# %% [markdown]
# 5) Unary   :   minus operator

# %%
 m = - (n)

# %%
n=7
n
# Out:
# 7

# %%
m = - n
m
# Out:
# -7
