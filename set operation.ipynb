# %% [markdown]
# # set operation

# %% [markdown]
# # 1) union  ( | )

# %% [raw]
# combines both sets, common elements take as once time

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a | b          # 3 , 4 take as once time
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
b | c
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
c | a | b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4}
# {3, 4, 5, 6}
# {8, 6, 7}

# %%
b.union(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # 2) intersection ( & )

# %% [markdown]
# only common elements

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
b.intersection (c)
# Out:
# {6}

# %%
c & a
# Out:
# set()

# %%
a & b
# Out:
# {3, 4}

# %%
a & b & c
# Out:
# set()

# %% [markdown]
# # 3) difference ( - )

# %% [raw]
# a - b => only print set a value, remove common from both set

# %%
b - a => only print set a value, remove common from both set

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
b - c
# Out:
# {3, 4, 5}

# %%
b - a
# Out:
# {5, 6}

# %% [markdown]
# # symmetric difference ( ^ )

# %% [raw]
#  all values from both set , remove common elem

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a ^ b
# Out:
# {1, 2, 5, 6}

# %%
a ^ c ^ b
# Out:
# {1, 2, 5, 7, 8}

# %% [markdown]
# # 1) update

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a.update(b)        # only a will change    (union)
                   # b is as it is

# %%
print(a)
print(b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4, 5, 6}

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
b.update(c)         # only b change

# %%
print(b)
print(c)
# Out:
# {3, 4, 5, 6, 7, 8}
# {8, 6, 7}

# %% [markdown]
# # 2) intersection update

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a.intersection_update(b)          # only change a

# %%
print(a)
print(b)
# Out:
# {3, 4}
# {3, 4, 5, 6}

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
c.intersection_update(a)      #only c change

# %%
print(a)
print(c)      # bcoz no common elem
# Out:
# {1, 2, 3, 4}
# set()

# %% [markdown]
# # 3) difference update

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a.difference_update(b)      # only a change

# %%
print(a)
print(b)
# Out:
# {1, 2}
# {3, 4, 5, 6}

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
c.difference_update(a)

# %%
print(a)
print(c)
# Out:
# {1, 2, 3, 4}
# {8, 6, 7}

# %% [markdown]
# # 4) symmetric difference

# %%
a = { 1 , 2 , 3 , 4 }
b = { 3 , 4 , 5 , 6 }
c = { 6 , 7 , 8 }

# %%
a.symmetric_difference_update(b)    # a change only

# %%
print(a)
print(b)    # b as it is
# Out:
# {1, 2, 5, 6}
# {3, 4, 5, 6}

# %% [markdown]
# # superset

# %% [raw]
# 1 set all elem are cover into second set

# %%
x={1,2,3,4,5,6}
y={1,2,3}
z={5,6,7}

# %%
x.issuperset(y)    # y che all elem in x
# Out:
# True

# %%
y.issuperset(z)
# Out:
# False

# %%
z.issuperset(x)
# Out:
# False

# %% [markdown]
# # subset

# %% [raw]
# 1 set all elem are cover into second set

# %%
x={1,2,3,4,5,6}
y={1,2,3}
z={5,6,7}

# %%
x.issubset(y)
# Out:
# False

# %%
y.issubset(z)
# Out:
# False

# %% [markdown]
# # disjoint

# %% [raw]
# no common elem

# %%
x={1,2,3,4,5,6}
y={1,2,3}
z={5,6,7}

# %%
x.isdisjoint(y)
# Out:
# False

# %%
x.isdisjoint(z)
# Out:
# False
