# %% [markdown]
# # strip()

# %% [raw]
# strip()    --> remove both side space
# rstrip()   --> remove left side space
# lstrip()   --> remove left side space

# %%
txt = " abc def ghi " 
 
txt.strip()
# Out:
# 'abc def ghi'

# %%
txt = " abc def ghi " 
 
txt.rstrip()
# Out:
# ' abc def ghi'

# %%
txt = " abc def ghi " 
 
txt.lstrip()
# Out:
# 'abc def ghi '

# %% [markdown]
# # join list

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']

# %%
print(list1)
print(list2)
# Out:
# ['one', 'two', 'three', 'four']
# ['five', 'six', 'seven', 'eight']

# %%
list3=list1 + list2
print(list3)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # append()

# %%
l1=[3,5.6,'pragati',74,(6+5j),False]
l1
# Out:
# [3, 5.6, 'pragati', 74, (6+5j), False]

# %%
l1.append(40)
l1
# Out:
# [3, 5.6, 'pragati', 74, (6+5j), False, 40]

# %% [markdown]
# # extend()

# %%
l2=[2,7,True,False,6,5.4]
l2
# Out:
# [2, 7, True, False, 6, 5.4]

# %%
l3=[3,2,4]
l3
# Out:
# [3, 2, 4]

# %%
l3.extend(l2)
l3
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
l3
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %% [markdown]
# # copy()

# %%
l3
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
l2
# Out:
# [2, 7, True, False, 6, 5.4]

# %%
l4=l3.copy()
l4
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
print(id(l3))     # in this, we used copy that's why id are different
print(id(l4))
# Out:
# 2143775998592
# 2143776190720

# %%
l4
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
l5=l4     # in this l4 & l5 are same ,that's why  same id
l5
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
print(id(l4))
print(id(l5))
# Out:
# 2143776190720
# 2143776190720

# %%
l4
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
l4.clear()

# %%
l5    # bcoz l5=l4 , in l4 we delete all the data
# Out:
# []

# %%
l2
# Out:
# [2, 7, True, False, 6, 5.4]

# %% [markdown]
# # insert(index,value)

# %%
l2.insert(3,6.6)
l2
# Out:
# [2, 7, True, 6.6, False, 6, 5.4]

# %%
l3
# Out:
# [3, 2, 4, 2, 7, True, False, 6, 5.4]

# %%
l3.insert(2,True)
l3
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %%
del l2

# %%
l3
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %% [markdown]
# # indexing

# %%
l3[4]
# Out:
# 2

# %%
l3[-5]
# Out:
# 7

# %%
t4=[3,4,6,3.4,'tejal','pragati']
t4
# Out:
# [3, 4, 6, 3.4, 'tejal', 'pragati']

# %%
t4[4][3]
# Out:
# 'a'

# %%
t4[5][0]
# Out:
# 'p'

# %%
l3
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %% [markdown]
# # slicing

# %%
l3[0:3]
# Out:
# [3, 2, True]

# %%
l3[-5:-2]
# Out:
# [7, True, False]

# %%
l3
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %%
l3[3:-1]
# Out:
# [4, 2, 7, True, False, 6]

# %%
l3[:]
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %%
l3
# Out:
# [3, 2, True, 4, 2, 7, True, False, 6, 5.4]

# %%
l3[: : 2]
# Out:
# [3, True, 2, True, 6]

# %%
l3[6:-2:1]
# Out:
# [True, False]

# %%
l3[: :-1]
# Out:
# [5.4, 6, False, True, 7, 2, 4, True, 2, 3]

# %% [markdown]
# # nested list -list inside list

# %%
l1=[2,4,6.6,(6+7j),True,False,3,[4,'tejal']]
l1
# Out:
# [2, 4, 6.6, (6+7j), True, False, 3, [4, 'tejal']]

# %%
len(l1)
# Out:
# 8

# %%
l1
# Out:
# [2, 4, 6.6, (6+7j), True, False, 3, [4, 'tejal']]

# %%
# remove 3 kel hot

# %%
l4=[2, 4, 6.6, (6+7j), True, False, [4, 'tejal']]
l4
# Out:
# [2, 4, 6.6, (6+7j), True, False, [4, 'tejal']]

# %% [markdown]
# # remove(value)

# %%
l4.remove(6.6)
l4
# Out:
# [2, 4, (6+7j), True, False, [4, 'tejal']]

# %%
l1
# Out:
# [2, 4, (6+7j), True, False, [4, 'tejal']]

# %%
l2=[3,3,2,5,3,5,6,7,7,8,8]
l2
# Out:
# [3, 3, 2, 5, 3, 5, 6, 7, 7, 8, 8]

# %% [markdown]
# # count(value)

# %%
l2.count(3)
# Out:
# 3

# %%
l2.count(7)
# Out:
# 2

# %% [markdown]
# # index(value)

# %%
l2
# Out:
# [3, 3, 2, 5, 3, 5, 6, 7, 7, 8, 8]

# %%
l2.index(5)
# Out:
# 3

# %% [markdown]
# # pop()

# %%
l1
# Out:
# [2, 4, (6+7j), True, False, [4, 'tejal']]

# %%
l1.pop()
# Out:
# [4, 'tejal']

# %%
l1
# Out:
# [2, 4, (6+7j), True, False]

# %%
l2
# Out:
# [3, 3, 2, 5, 3, 5, 6, 7, 7, 8, 8]

# %%
l3=[4,8.4,(3+6j),True,False,9,'Tejal']
l3
# Out:
# [4, 8.4, (3+6j), True, False, 9, 'Tejal']

# %% [markdown]
# # pop(index)

# %%
l3.pop(3)
# Out:
# True

# %% [markdown]
# # reverse()

# %%
l3
# Out:
# [4, 8.4, (3+6j), False, 9, 'Tejal']

# %%
l3.reverse()
l3
# Out:
# ['Tejal', 9, False, (3+6j), 8.4, 4]

# %% [markdown]
# # sort()

# %% [raw]
# in sort same datatype or int,float,bool can consider

# %%
l3
# Out:
# ['Tejal', 9, False, (3+6j), 8.4, 4]

# %%
l2=[1,1,3.4,6,8,True,False]
l2
# Out:
# [1, 1, 3.4, 6, 8, True, False]

# %%
l2.sort()
l2
# Out:
# [False, 1, 1, True, 3.4, 6, 8]

# %%
l2
# Out:
# [False, 1, 1, True, 3.4, 6, 8]

# %%
l2.sort(reverse=True)
l2
# Out:
# [8, 6, 3.4, 1, 1, True, False]

# %% [markdown]
# # tunning

# %%
l=[1,3,5,6.6]
l
# Out:
# [1, 3, 5, 6.6]

# %%
l.sort()
l            # parameter tunning
# Out:
# [1, 3, 5, 6.6]

# %%
l.sort(reverse=True)
l                            # hyperparameter tunning
# Out:
# [6.6, 5, 3, 1]

# %% [markdown]
# # list membership

# %% [raw]
#  in
#  not in

# %%
l2
# Out:
# [8, 6, 3.4, 1, 1, True, False]

# %%
3.4 in l2
# Out:
# True

# %%
10 in l2
# Out:
# False

# %%
10 not in l2
# Out:
# True

# %%
5 not in l2
# Out:
# True

# %% [markdown]
# # all   - all value must be true , 0=False
# # any   - any 1 value true

# %%
l2
# Out:
# [8, 6, 3.4, 1, 1, True, False]

# %%
any(l2)
# Out:
# True

# %%
all(l2)     # 3.4
# Out:
# False

# %%
l=[1,7,5,(4+5j),'tejal']
l
# Out:
# [1, 7, 5, (4+5j), 'tejal']

# %%
any(l)
# Out:
# True

# %%
l=[4,8,(4+6j),True]
l
# Out:
# [4, 8, (4+6j), True]

# %%
any(l)
# Out:
# True

# %%
all(l)
# Out:
# True

# %%
l=[5,8,0,5,(5+8j)]
l
# Out:
# [5, 8, 0, 5, (5+8j)]

# %%
any(l)
# Out:
# True

# %%
all(l)     #bcoz of 0
# Out:
# False

# %%
t=[5,False,1.5,(6+7j),4,'teajal']
t
# Out:
# [5, False, 1.5, (6+7j), 4, 'teajal']

# %%
any(t)
# Out:
# True

# %%
all(t)     # bcoz of False
# Out:
# False
