# %%
a=5
a
# Out:
# 5

# %%
"pragati"
# Out:
# 'pragati'

# %%
'pragati'
# Out:
# 'pragati'

# %%
"pragati'          #string "" or ''
# Out:
#   Cell In[4], line 1
#     "pragati'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''hello
dear
pragati'''
# Out:
# 'hello\ndear\npragati'

# %%
var=6
var
# Out:
# 6

# %%
import keyword             #keyword not allow as a variable
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
for=136
for                      #keyword not allow as a variable
# Out:
#   Cell In[20], line 1
#     for=136
#        ^
# SyntaxError: invalid syntax

# %%
tej=123        # variable is a case sentitive
Tej             # tej is not equal to Tej
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 tej=123
# ----> 2 Tej
#
# NameError: name 'Tej' is not defined

# %%
int1=7
int1
# Out:
# 7

# %%
_tej=16
_tej              #only _ is valid
# Out:
# 16

# %%
tej@=14
tej@             # special character not allowed
# Out:
#   Cell In[19], line 2
#     tej@
#         ^
# SyntaxError: invalid syntax

# %%
16tej=16
16tej           #variable not start with digit
# Out:
#   Cell In[17], line 1
#     16tej=16
#      ^
# SyntaxError: invalid decimal literal

# %%
# variable is case sensitive
# special chara.are not allowed, only _allowed
# variable does not start with digit but can ends with digit
# keyword not allowed as a variable

# %% [markdown]
# # variable or object or identifier
# # value or datatype

# %% [markdown]
# # variable store a data in memory location
