# %% [markdown]
# VARIABLE

# %%
t=16           # t is variable
t             # 16 is value
# Out:
# 16

# %%
nit=34
Nit          # variable is case sensitive
             # name error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit=34
# ----> 2 Nit
#
# NameError: name 'Nit' is not defined

# %%
april=2
april
# Out:
# 2

# %%
fruit     # name error
          # text always in string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fruit
#
# NameError: name 'fruit' is not defined

# %%
"fruit"  # single line string " "
# Out:
# 'fruit'

# %%
'pragati'     # single line  string ' '
# Out:
# 'pragati'

# %%
'apple"     # syntax error
# Out:
#   Cell In[24], line 1
#     'apple"
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"you'       # syntax error
# Out:
#   Cell In[25], line 1
#     "you'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''you 
are very
very genious          
pragati'''           # multi line string '''  '''
# Out:
# 'you \nare very\nvery genious     \npragati'

# %%
'''you are  
best'''     #/n new line
# Out:
# 'you are \nbest'

# %% [markdown]
# FUNCTION

# %%
a=5            # id()  inbuilt function
id(a)         #  adress of memory location
# Out:
# 140717242033192

# %%
a=5
print(a)         #print()  inbuilt function
# Out:
# 5

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# KEYWORD

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
 with=2       # keyword not allow as variable
with
# Out:
#   Cell In[29], line 1
#     with=2
#     ^
# IndentationError: unexpected indent

# %%
For=4         # for is keyword
For           # not For
# Out:
# 4

# %%
1a=4     # variable does not start with digit bt it can ends with digit
# Out:
#   Cell In[31], line 1
#     1a=4
#     ^
# SyntaxError: invalid decimal literal

# %%
ahy134=678
ahy134
# Out:
# 678

# %%
dgh@=6  
dgh@          # special chara not allow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dgh@=6
#
# NameError: name 'dgh' is not defined

# %%
_fruit=66
_fruit        # only _ is allowed
# Out:
# 66

# %%
# variables are case sensitive.
# variable does not starts with digit.
# variable does not allow special chara,only_ is allowed.
# keyword not used as variable.

# %%
#  variable = object = identifier

# %%
# value = datatypes

# %%
# syntax:
    variable = value
