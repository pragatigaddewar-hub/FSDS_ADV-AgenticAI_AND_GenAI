# %% [markdown]
# # import

# %%
sqrt(49)        # direct sqrt is not a function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sqrt(49)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# # import math

# %%
import math
math.sqrt(49)     # math is module  then sqrt() is inbuld function
# Out:
# 7.0

# %%
x=2.3          
x
# Out:
# 2.3

# %%
math.floor(2.3)             # 2 is floor ( floor means consider their lower value)
# Out:
# 2

# %%
math.ceil( 5.4)            # 6 is  ceil (ceil means consider their upper value)
# Out:
# 6

# %%
math.floor(4.5)
# Out:
# 4

# %%
math.ceil(6.8)
# Out:
# 7

# %%
round(5.4)
# Out:
# 5

# %%
round(4.3)
# Out:
# 4

# %%
t.floor(4.4)     # m is not a function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t.floor(4.4)     # m is not a function
#
# NameError: name 't' is not defined

# %% [markdown]
# # import math as

# %%
import math as t
t.floor(4.5)
# Out:
# 4

# %%
t.ceil(6.8)
# Out:
# 7

# %%
# all codes are run at a time that's calles code optimization

# %% [markdown]
# # from math import *

# %%
from math import * 
print(math.floor(5.4))            
print(math.ceil(5.7))              
print(math.pow(5,3))             # power & sqrt is in float
print(math.sqrt(64))
# Out:
# 5
# 6
# 125.0
# 8.0

# %%
print(math.ceil(5.8))
# Out:
# 6

# %% [markdown]
# # input()

# %%
x=input()   #  bcoz in input whatever you put,it always consider as a string
x
# Out:
#  5
# '5'

# %%
x=input()               #  2 input => 2 console
y=input()
z=x+y                   # str1 + str1 =str1str2
print(z)
# Out:
#  4
#  5
# 45

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# type casting is use for str to in

# %%
f=int(input("enter a number:"))
t=int(input("enter a number:"))      # using int we convert str into int
print(f*t)
# Out:
# enter a number: 5
# enter a number: 6
# 30

# %%
print(type(f*t))
# Out:
# <class 'int'>

# %% [markdown]
# # input with indexing

# %%
f=input('enter a number:')[1:4]

print(f)
# Out:
# enter a number: 74837637
# 483

# %%
t=input('enter a string:')[3:]
print(t)
# Out:
# enter a string: fullrani
# lrani

# %%
t=int(input('enter a number:'))[4:7]      # int is not used during indexing and slicing
print(t)
# Out:
# enter a number: t37823y22732
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 t=int(input('enter a number:'))[4:7]      # int is not used during indexing and slicing
#       2 print(t)
#
# ValueError: invalid literal for int() with base 10: 't37823y22732'

# %%
T=int(input('enter a number:'))[5]
print(T)
# Out:
# enter a number: 46456457
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 T=int(input('enter a number:'))[5]
#       2 print(T)
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# # input function with eval for expression

# %%
x=input('enter a string')     # this is expression not no.
print(x)                      # it involves no. & operator
# Out:
# enter a string 4+6-3
# 4+6-3

# %%
y=int(input('enter a string           # in expression int is not allow
print(y)
# Out:
#   Cell In[5], line 1
#     y=int(input('enter a string           # in expression int is not allow
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
y=eval(input('enter a string'))
print(y)
# Out:
# enter a string 8+6+8-2*6
# 10

# %%
w=eval(input('enter a string'))
print(w)
# Out:
# enter a string 6*4
# 24
