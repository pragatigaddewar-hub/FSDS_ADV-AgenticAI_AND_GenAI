# %% [markdown]
# NUMBER

# %%
5
# Out:
# 5

# %%
3
# Out:
# 3

# %% [markdown]
# operators

# %%
10+4
# Out:
# 14

# %%
54-43
# Out:
# 11

# %%
6+3
# Out:
# 9

# %%
14-5
# Out:
# 9

# %%
10*4
# Out:
# 40
