# %% [markdown]
# # Numpy

# %%
list=[1,2,4,5]
list
# Out:
# [1, 2, 4, 5]

# %%
import numpy as np

# %%
arr=np.array(list)

# %%
arr
# Out:
# array([1, 2, 4, 5])

# %%
m=np.random.randint(1,10,(4,6))      # 1-9
m                                    # 4 row , 6 column
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
print(m)       # 4*6
# Out:
# [[1 6 4 1 2 5]
#  [5 4 1 9 3 3]
#  [9 9 8 6 1 5]
#  [5 9 1 8 7 8]]

# %%
m[0]   # 0th row indexing
# Out:
# array([1, 6, 4, 1, 2, 5], dtype=int32)

# %%
m[-3]    # -3 th row
# Out:
# array([5, 4, 1, 9, 3, 3], dtype=int32)

# %%
m[2:5]          #  2th - 4th row slicing
# Out:
# array([[9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
m[ : ]    # all
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
len(m)      # no. of rows
# Out:
# 4

# %%
m[0:3]
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5]], dtype=int32)

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %% [markdown]
# # column

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
m[ :,0]    # 0th column
# Out:
# array([1, 5, 9, 5], dtype=int32)

# %%
m[ :,-3]  # -3th column
# Out:
# array([1, 9, 6, 8], dtype=int32)

# %% [markdown]
# # array

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
m[2,3]       # 2nd row , 3rd column
# Out:
# np.int32(6)

# %%
m[0,-3]      # 0th row , -3th column
# Out:
# np.int32(1)

# %%
m[1:3 , 2:5]      # 1-2th row , 2-4th column
# Out:
# array([[1, 9, 3],
#        [8, 6, 1]], dtype=int32)

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %% [markdown]
# # shape , reshape

# %%
m.shape       # total no. 24
# Out:
# (4, 6)

# %%
m.reshape(6,4)     # so reshape also is of 24 no.
# Out:
# array([[1, 6, 4, 1],
#        [2, 5, 5, 4],
#        [1, 9, 3, 3],
#        [9, 9, 8, 6],
#        [1, 5, 5, 9],
#        [1, 8, 7, 8]], dtype=int32)

# %% [markdown]
# # masking/filter

# %%
m
# Out:
# array([[1, 6, 4, 1, 2, 5],
#        [5, 4, 1, 9, 3, 3],
#        [9, 9, 8, 6, 1, 5],
#        [5, 9, 1, 8, 7, 8]], dtype=int32)

# %%
m<3      # condition - ans in True,False
# Out:
# array([[ True, False, False,  True,  True, False],
#        [False, False,  True, False, False, False],
#        [False, False, False, False,  True, False],
#        [False, False,  True, False, False, False]])

# %%
m[m<5]
# Out:
# array([1, 4, 1, 2, 4, 1, 3, 3, 1, 1], dtype=int32)

# %%
m[m!=2]
# Out:
# array([1, 6, 4, 1, 5, 5, 4, 1, 9, 3, 3, 9, 9, 8, 6, 1, 5, 5, 9, 1, 8, 7,
#        8], dtype=int32)

# %% [markdown]
# # convert image into array

# %% [markdown]
# # image analysis using np,PIL

# %%
import matplotlib.pyplot as plt   #matplotlib for visualization  (graph)

# %%
from PIL import Image   # Python Imaging Libraby

# %%
tiger_img=Image.open(r'C:\Users\LENOVO\Downloads\tiger_img.jpg')

# %%
tiger_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=643x360>

# %%
type(tiger_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
tiger_arr=np.asarray(tiger_img)
tiger_arr
# Out:
# array([[[123,  71,  23],
#         [124,  72,  24],
#         [125,  73,  25],
#         ...,
#         [246, 177,  60],
#         [246, 177,  60],
#         [246, 177,  60]],
#
#        [[121,  71,  22],
#         [123,  71,  23],
#         [124,  72,  24],
#         ...,
#         [246, 177,  60],
#         [246, 177,  60],
#         [246, 177,  60]],
#
#        [[120,  69,  22],
#         [121,  71,  22],
#         [122,  72,  23],
#         ...,
#         [246, 177,  60],
#         [246, 177,  60],
#         [246, 177,  60]],
#
#        ...,
#
#        [[ 93,  58,  38],
#         [ 87,  52,  32],
#         [ 85,  52,  33],
#         ...,
#         [137,  75,  36],
#         [135,  73,  34],
#         [134,  72,  33]],
#
#        [[101,  66,  44],
#         [ 94,  59,  39],
#         [ 89,  57,  36],
#         ...,
#         [135,  73,  36],
#         [134,  72,  35],
#         [132,  70,  33]],
#
#        [[ 98,  63,  41],
#         [101,  66,  44],
#         [ 96,  61,  41],
# ...

# %%
plt.imshow(tiger_img)

# %%
tiger_arr.shape
# Out:
# (360, 643, 3)
