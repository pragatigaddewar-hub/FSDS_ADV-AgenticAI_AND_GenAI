# %%
4
# Out:
# 4

# %%
6-3
# Out:
# 3

# %%
4+7
# Out:
# 11

# %%
_         # means it stored previous value
# Out:
# 11

# %%
_+2
# Out:
# 13

# %%
_*4
# Out:
# 52

# %%
_/2
# Out:
# 26.0

# %%
10/2     # float division
# Out:
# 5.0

# %%
8//2    # int division
# Out:
# 4

# %%
5*3+5-6/3
# Out:
# 18.0

# %%
(5-2)+4
# Out:
# 7
